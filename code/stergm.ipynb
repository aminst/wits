# %%
library(statnet)
library(stats)
# Out:
# Loading required package: tergm
#
# Loading required package: ergm
#
# Loading required package: network
#
# network: Classes for Relational Data
# Version 1.16.1 created on 2020-10-06.
# copyright (c) 2005, Carter T. Butts, University of California-Irvine
#                     Mark S. Handcock, University of California -- Los Angeles
#                     David R. Hunter, Penn State University
#                     Martina Morris, University of Washington
#                     Skye Bender-deMoll, University of Washington
#  For citation information, type citation("network").
#  Type help("network-package") to get started.
#
#
#
# ergm: version 3.11.0, created on 2020-10-14
# Copyright (c) 2020, Mark S. Handcock, University of California -- Los Angeles
#                     David R. Hunter, Penn State University
#                     Carter T. Butts, University of California -- Irvine
#                     Steven M. Goodreau, University of Washington
# ...

# %%
el_2011 = read.csv("../data/2011/edgelist_disparity.csv", stringsAsFactors = FALSE)
nl_2011 = read.csv("../data/2011/nodelist.csv", stringsAsFactors = FALSE)

nl_2011$gdp_us_dollar <- log(nl_2011$gdp_us_dollar)
nl_2011$area <- log(nl_2011$area)
nl_2011$population <- log(nl_2011$population)
nl_2011$gdp_per_capita <- log(nl_2011$gdp_per_capita)
nl_2011$gdp_us_dollar = as.numeric(scale(nl_2011$gdp_us_dollar))
nl_2011$gdp_growth = as.numeric(scale(nl_2011$gdp_growth))
nl_2011$inflation_rate = as.numeric(scale(nl_2011$inflation_rate))
nl_2011$population = as.numeric(scale(nl_2011$population))
nl_2011$gdp_per_capita = as.numeric(scale(nl_2011$gdp_per_capita))
nl_2011$agriculture_forestry_fishing_of_gdp = as.numeric(scale(nl_2011$agriculture_forestry_fishing_of_gdp))
nl_2011$industry_of_gdp = as.numeric(scale(nl_2011$industry_of_gdp))
nl_2011$merchandise_of_gdp = as.numeric(scale(nl_2011$merchandise_of_gdp))
nl_2011$net_barter_of_trade = as.numeric(scale(nl_2011$net_barter_of_trade))
nl_2011$foreign_direct_investment_inflows = as.numeric(scale(nl_2011$foreign_direct_investment_inflows))

net_2011 = network(el_2011, directed = TRUE, matrix.type = 'edgelist', vertex.attr=nl_2011, vertex.attrnames=colnames(nl_2011), ignore.eval = FALSE, names.eval='trade')
set.edge.value(net_2011, "trade", el_2011$weight)
net_2011
# Out:
#  Network attributes:
#   vertices = 166
#   directed = TRUE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#   total edges= 3417
#     missing edges= 0
#     non-missing edges= 3417
#
#  Vertex attribute names:
#     agriculture_forestry_fishing_of_gdp area continent country_iso3 foreign_direct_investment_inflows gdp_growth gdp_per_capita gdp_us_dollar industry_of_gdp inflation_rate landlocked langoff_1 merchandise_of_gdp net_barter_of_trade population vertex.names
#
#  Edge attribute names not shown

# %%
el_2013 = read.csv("../data/2013/edgelist_disparity.csv", stringsAsFactors = FALSE)
nl_2013 = read.csv("../data/2013/nodelist.csv", stringsAsFactors = FALSE)

nl_2013$gdp_us_dollar <- log(nl_2013$gdp_us_dollar)
nl_2013$area <- log(nl_2013$area)
nl_2013$population <- log(nl_2013$population)
nl_2013$gdp_per_capita <- log(nl_2013$gdp_per_capita)
nl_2013$gdp_us_dollar = as.numeric(scale(nl_2013$gdp_us_dollar))
nl_2013$gdp_growth = as.numeric(scale(nl_2013$gdp_growth))
nl_2013$inflation_rate = as.numeric(scale(nl_2013$inflation_rate))
nl_2013$population = as.numeric(scale(nl_2013$population))
nl_2013$gdp_per_capita = as.numeric(scale(nl_2013$gdp_per_capita))
nl_2013$agriculture_forestry_fishing_of_gdp = as.numeric(scale(nl_2013$agriculture_forestry_fishing_of_gdp))
nl_2013$industry_of_gdp = as.numeric(scale(nl_2013$industry_of_gdp))
nl_2013$merchandise_of_gdp = as.numeric(scale(nl_2013$merchandise_of_gdp))
nl_2013$net_barter_of_trade = as.numeric(scale(nl_2013$net_barter_of_trade))
nl_2013$foreign_direct_investment_inflows = as.numeric(scale(nl_2013$foreign_direct_investment_inflows))

net_2013 = network(el_2013, directed = TRUE, matrix.type = 'edgelist', vertex.attr=nl_2013, vertex.attrnames=colnames(nl_2013), ignore.eval = FALSE, names.eval='trade')
set.edge.value(net_2013, "trade", el_2011$weight)
net_2013
# Out:
#  Network attributes:
#   vertices = 166
#   directed = TRUE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#   total edges= 3473
#     missing edges= 0
#     non-missing edges= 3473
#
#  Vertex attribute names:
#     agriculture_forestry_fishing_of_gdp area continent country_iso3 foreign_direct_investment_inflows gdp_growth gdp_per_capita gdp_us_dollar industry_of_gdp inflation_rate landlocked langoff_1 merchandise_of_gdp net_barter_of_trade population vertex.names
#
#  Edge attribute names not shown

# %%
el_2015 = read.csv("../data/2015/edgelist_disparity.csv", stringsAsFactors = FALSE)
nl_2015 = read.csv("../data/2015/nodelist.csv", stringsAsFactors = FALSE)

nl_2015$gdp_us_dollar <- log(nl_2015$gdp_us_dollar)
nl_2015$area <- log(nl_2015$area)
nl_2015$population <- log(nl_2015$population)
nl_2015$gdp_per_capita <- log(nl_2015$gdp_per_capita)
nl_2015$gdp_us_dollar = as.numeric(scale(nl_2015$gdp_us_dollar))
nl_2015$gdp_growth = as.numeric(scale(nl_2015$gdp_growth))
nl_2015$inflation_rate = as.numeric(scale(nl_2015$inflation_rate))
nl_2015$population = as.numeric(scale(nl_2015$population))
nl_2015$gdp_per_capita = as.numeric(scale(nl_2015$gdp_per_capita))
nl_2015$agriculture_forestry_fishing_of_gdp = as.numeric(scale(nl_2015$agriculture_forestry_fishing_of_gdp))
nl_2015$industry_of_gdp = as.numeric(scale(nl_2015$industry_of_gdp))
nl_2015$merchandise_of_gdp = as.numeric(scale(nl_2015$merchandise_of_gdp))
nl_2015$net_barter_of_trade = as.numeric(scale(nl_2015$net_barter_of_trade))
nl_2015$foreign_direct_investment_inflows = as.numeric(scale(nl_2015$foreign_direct_investment_inflows))

net_2015 = network(el_2015, directed = TRUE, matrix.type = 'edgelist', vertex.attr=nl_2015, vertex.attrnames=colnames(nl_2015), ignore.eval = FALSE, names.eval='trade')
set.edge.value(net_2015, "trade", el_2015$weight)
net_2015
# Out:
#  Network attributes:
#   vertices = 166
#   directed = TRUE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#   total edges= 3369
#     missing edges= 0
#     non-missing edges= 3369
#
#  Vertex attribute names:
#     agriculture_forestry_fishing_of_gdp area continent country_iso3 foreign_direct_investment_inflows gdp_growth gdp_per_capita gdp_us_dollar industry_of_gdp inflation_rate landlocked langoff_1 merchandise_of_gdp net_barter_of_trade population vertex.names
#
#  Edge attribute names not shown

# %%
el_2017 = read.csv("../data/2017/edgelist_disparity.csv", stringsAsFactors = FALSE)
nl_2017 = read.csv("../data/2017/nodelist.csv", stringsAsFactors = FALSE)

nl_2017$gdp_us_dollar <- log(nl_2017$gdp_us_dollar)
nl_2017$area <- log(nl_2017$area)
nl_2017$population <- log(nl_2017$population)
nl_2017$gdp_per_capita <- log(nl_2017$gdp_per_capita)
nl_2017$gdp_us_dollar = as.numeric(scale(nl_2017$gdp_us_dollar))
nl_2017$gdp_growth = as.numeric(scale(nl_2017$gdp_growth))
nl_2017$inflation_rate = as.numeric(scale(nl_2017$inflation_rate))
nl_2017$population = as.numeric(scale(nl_2017$population))
nl_2017$gdp_per_capita = as.numeric(scale(nl_2017$gdp_per_capita))
nl_2017$agriculture_forestry_fishing_of_gdp = as.numeric(scale(nl_2017$agriculture_forestry_fishing_of_gdp))
nl_2017$industry_of_gdp = as.numeric(scale(nl_2017$industry_of_gdp))
nl_2017$merchandise_of_gdp = as.numeric(scale(nl_2017$merchandise_of_gdp))
nl_2017$net_barter_of_trade = as.numeric(scale(nl_2017$net_barter_of_trade))
nl_2017$foreign_direct_investment_inflows = as.numeric(scale(nl_2017$foreign_direct_investment_inflows))

net_2017 = network(el_2017, directed = TRUE, matrix.type = 'edgelist', vertex.attr=nl_2017, vertex.attrnames=colnames(nl_2017), ignore.eval = FALSE, names.eval='trade')
set.edge.value(net_2017, "trade", el_2017$weight)
net_2017
# Out:
#  Network attributes:
#   vertices = 166
#   directed = TRUE
#   hyper = FALSE
#   loops = FALSE
#   multiple = FALSE
#   bipartite = FALSE
#   total edges= 3431
#     missing edges= 0
#     non-missing edges= 3431
#
#  Vertex attribute names:
#     agriculture_forestry_fishing_of_gdp area continent country_iso3 foreign_direct_investment_inflows gdp_growth gdp_per_capita gdp_us_dollar industry_of_gdp inflation_rate landlocked langoff_1 merchandise_of_gdp net_barter_of_trade population vertex.names
#
#  Edge attribute names not shown

# %%
set.seed(19746)
stergm <- stergm(
                list(net_2011, net_2013, net_2015, net_2017),
                formation = ~ edges +
                        mutual +
                        triangles + 
                        nodecov("gdp_us_dollar") +
                        absdiff("gdp_us_dollar") +
                        nodecov("inflation_rate") +
                        absdiff("inflation_rate") +
                        nodecov("gdp_growth") +
                        absdiff("gdp_growth") +
                        nodematch("landlocked") +
                        nodematch("langoff_1") +
                        nodecov("agriculture_forestry_fishing_of_gdp") +
                        absdiff("agriculture_forestry_fishing_of_gdp") +
                        nodecov("industry_of_gdp") +
                        absdiff("industry_of_gdp") +
                        nodecov("merchandise_of_gdp") +
                        absdiff("merchandise_of_gdp") +
                        nodecov("net_barter_of_trade") +
                        absdiff("net_barter_of_trade") +
                        nodecov("foreign_direct_investment_inflows") +
                        absdiff("foreign_direct_investment_inflows"),
                dissolution = ~ edges +
                        mutual +
                        triangles + 
                        nodecov("gdp_us_dollar") +
                        absdiff("gdp_us_dollar") +
                        nodecov("inflation_rate") +
                        absdiff("inflation_rate") +
                        nodecov("gdp_growth") +
                        absdiff("gdp_growth") +
                        nodematch("landlocked") +
                        nodematch("langoff_1") +
                        nodecov("agriculture_forestry_fishing_of_gdp") +
                        absdiff("agriculture_forestry_fishing_of_gdp") +
                        nodecov("industry_of_gdp") +
                        absdiff("industry_of_gdp") +
                        nodecov("merchandise_of_gdp") +
                        absdiff("merchandise_of_gdp") +
                        nodecov("net_barter_of_trade") +
                        absdiff("net_barter_of_trade") +
                        nodecov("foreign_direct_investment_inflows") +
                        absdiff("foreign_direct_investment_inflows"),
                estimate="CMLE"
    )
# Out:
# Warning message in stergm.CMLE(nw, formation, dissolution, constraints, times, offset.coef.form, :
# “'times' argument was not provided to specify sampling time points for a list. Modeling transition between successive networks jointly. This behavior may change in the future.”
# Fitting formation...
#
# Starting maximum pseudolikelihood estimation (MPLE):
#
# Evaluating the predictor and response matrix.
#
# Maximizing the pseudolikelihood.
#
# Finished MPLE.
#
# Starting Monte Carlo maximum likelihood estimation (MCMLE):
#
# Iteration 1 of at most 20:
#
# Optimizing with step length 0.340023739085968.
#
# The log-likelihood improved by 2.906.
#
# Iteration 2 of at most 20:
#
# Optimizing with step length 0.399886998132594.
#
# The log-likelihood improved by 1.857.
#
# Iteration 3 of at most 20:
#
# Optimizing with step length 0.982417502116328.
#
# The log-likelihood improved by 2.38.
#
# Iteration 4 of at most 20:
#
# Optimizing with step length 0.905469683926525.
#
# ...

# %%
summary(stergm)
# Out:
# ...
# Summary of formation model fit
# ...
#
# Formula:   ~edges + mutual + triangles + nodecov("gdp_us_dollar") + absdiff("gdp_us_dollar") +
#     nodecov("inflation_rate") + absdiff("inflation_rate") + nodecov("gdp_growth") +
#     absdiff("gdp_growth") + nodematch("landlocked") + nodematch("langoff_1") +
#     nodecov("agriculture_forestry_fishing_of_gdp") + absdiff("agriculture_forestry_fishing_of_gdp") +
#     nodecov("industry_of_gdp") + absdiff("industry_of_gdp") +
#     nodecov("merchandise_of_gdp") + absdiff("merchandise_of_gdp") +
#     nodecov("net_barter_of_trade") + absdiff("net_barter_of_trade") +
#     nodecov("foreign_direct_investment_inflows") + absdiff("foreign_direct_investment_inflows")
#
# Call:
# ergm(formula = formation, constraints = constraints.form, offset.coef = offset.coef.form,
#     eval.loglik = eval.loglik, estimate = ergm.estimate, control = control$CMLE.control.form,
#     verbose = verbose)
#
# Iterations:  6 out of 20
#
# Monte Carlo MLE Results:
# ...

# %%
mcmc.diagnostics(stergm, which = c("plots"))
# Out:
# ...
# Formation fit diagnostics
# ...
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# MCMC diagnostics shown here are from the last round of simulation, prior to computation of final parameter estimates. Because the final estimates are refinements of those used for this simulation run, these diagnostics may understate model performance. To directly assess the performance of the final model on in-model statistics, please use the GOF command: gof(ergmFitObject, GOF=~model).
#
# ...
# Dissolution fit diagnostics
# ...
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# ...
